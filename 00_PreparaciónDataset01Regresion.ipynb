# %% [markdown]
# # Preparación del dataset de ventas de vehículos

# %% [markdown]
# ## 1. Librerias y configuraciones previas

# %%
# Tratamiento de datos
# ==============================================================================
import pandas as pd
import numpy as np


# Gestion de librerias
# ==============================================================================
from importlib import reload


# Matemáticas y estadísticas
# ==============================================================================
import math

# Preparación de datos
# ==============================================================================
from sklearn.impute import KNNImputer
from sklearn.impute import SimpleImputer
from sklearn.neighbors import LocalOutlierFactor


# Gráficos
# ==============================================================================
import matplotlib.pyplot as plt
from matplotlib import style
import seaborn as sns

# Configuración warnings
# ==============================================================================
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## 2. Funciones

# %%
#reload(utils.funciones)

# Funciones externas
# ==============================================================================
from utils.funciones import multiple_plot

# %% [markdown]
# ## 3. Carga del dataset

# %% [markdown]
# Este dataset extraido de *Kaggle* (nombrado: **car details v4.csv** ) contiene información sobre **vehículos usados**, los cuales serán usados para la predicción de precios de venta, a partir de las diferentes variables.
#
# A continuación una breve descripción de las variables:
#
# ****
#
# | Campo | Descripción | Ejempo |
# | :--- | :--- |:--- |
# | Make | Marca  | Honda |
# | Model | Modelo  | Amaze 1.2 VX i-VTEC |
# | Price | Precio  | 505000 |
# | Year | Año  | 2017 |
# | Kilometer | Kilometraje  | 87150 |
# | Fuel Type | Tipo de combustible  | Petrol |
# | Transmission | Tipo de transmisión  | Manual |
# | Location | Ubicación  | Pune |
# | Color | Color  | Grey |
# | Owner | Número de propietarios previos  | First |
# | Seller Type | Tipo de vendedor  | Corporate |
# | Engine | Tipo de motor  | 1198 cc |
# | Max Power | Potencia máxima del motor  | 87 bhp @ 6000 rpm |
# | Max Torque | Torque máximo del motor  | 109 Nm @ 4500 rpm |
# | Drivetrain | Tipo de tracción  | FWD |
# | Length | Longitud  | 3990 |
# | Width | Anchura  | 1680 |
# | Height | Altura  | 1505 |
# | Seating Capacity | Capacidad de asientos  | 5 |
# | Fuel Tank Capacity | Capacidad del tanque de combustible  | 35 |
#
#
# ****
#
#
# Url origen datos: https://www.kaggle.com/datasets/nehalbirla/vehicle-dataset-from-cardekho?select=car+details+v4.csv

# %%
#Cargar el dataset
d=pd.read_csv('./datasets/01_car details v4.csv')

# %%
## Cargar datos con colab
## =============================================================================

#from google.colab import drive 
#import os

#drive.mount('/gdrive')

# %%
#os.chdir("/gdrive/MyDrive/ModelosCuantitativosPython/Notebooks")
#!ls

# %%
d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2059 entries, 0 to 2058
# Data columns (total 20 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Make                2059 non-null   object
#  1   Model               2059 non-null   object
#  2   Price               2059 non-null   int64
#  3   Year                2059 non-null   int64
#  4   Kilometer           2059 non-null   int64
#  5   Fuel Type           2059 non-null   object
#  6   Transmission        2059 non-null   object
#  7   Location            2059 non-null   object
#  8   Color               2059 non-null   object
#  9   Owner               2059 non-null   object
#  10  Seller Type         2059 non-null   object
#  11  Engine              1979 non-null   object
#  12  Max Power           1979 non-null   object
#  13  Max Torque          1979 non-null   object
#  14  Drivetrain          1923 non-null   object
#  15  Length              1995 non-null   float64
#  16  Width               1995 non-null   float64
#  17  Height              1995 non-null   float64
#  18  Seating Capacity    1995 non-null   float64
#  19  Fuel Tank Capacity  1946 non-null   float64
# dtypes: float64(5), int64(3), object(12)
# memory usage: 321.8+ KB

# %%
d.head(2)
# Out:
#             Make                Model   Price  Year  Kilometer Fuel Type  \
# 0          Honda  Amaze 1.2 VX i-VTEC  505000  2017      87150    Petrol
# 1  Maruti Suzuki      Swift DZire VDI  450000  2014      75000    Diesel
#
#   Transmission  Location  Color   Owner Seller Type   Engine  \
# 0       Manual      Pune   Grey   First   Corporate  1198 cc
# 1       Manual  Ludhiana  White  Second  Individual  1248 cc
#
#            Max Power         Max Torque Drivetrain  Length   Width  Height  \
# 0  87 bhp @ 6000 rpm  109 Nm @ 4500 rpm        FWD  3990.0  1680.0  1505.0
# 1  74 bhp @ 4000 rpm  190 Nm @ 2000 rpm        FWD  3995.0  1695.0  1555.0
#
#    Seating Capacity  Fuel Tank Capacity
# 0               5.0                35.0
# 1               5.0                42.0

# %% [markdown]
# ## 4. Limpieza de datos (Data Cleaning)

# %%
#Borrando columnas que no se utilizarán

d.drop([ 'Model', 'Location', 'Color', 'Max Power', 'Max Torque'], axis='columns', inplace=True)

# %%
#Se limpia la variable Engine para convertirla en una variable numérica

#Se borra todos los valores ' cc'
d['Engine'] = d['Engine'].str.replace(' cc', '')

#se convierte a variable tipo float
d['Engine'] = d['Engine'].astype('float64')
d["Engine"].dtype
# Out:
# dtype('float64')

# %%
#Verificación y eliminación de registros duplicados

#Verificación de registros duplicados
d.loc[d.duplicated()]
# Out:
#                Make    Price  Year  Kilometer Fuel Type Transmission   Owner  \
# 258             BMW  2950000  2015      84700    Diesel    Automatic  Second
# 923         Renault   315000  2017      15507    Petrol       Manual   First
# 1217  Maruti Suzuki   725000  2019      11874    Petrol    Automatic   First
# 1555        Hyundai   649000  2020      52236    Petrol       Manual   First
# 1603  Mercedes-Benz  7475000  2021      13000    Diesel    Automatic   First
# 1856          Skoda  1390000  2017      56000    Petrol    Automatic   First
#
#      Seller Type  Engine Drivetrain  Length   Width  Height  Seating Capacity  \
# 258   Individual  2993.0        AWD  4886.0  1938.0  1762.0               5.0
# 923   Individual   799.0        FWD  3679.0  1579.0  1478.0               5.0
# 1217  Individual  1197.0        FWD  3840.0  1735.0  1530.0               5.0
# 1555  Individual  1197.0        FWD  3765.0  1660.0  1520.0               5.0
# 1603  Individual  1950.0        RWD  5063.0  1860.0  1494.0               5.0
# 1856  Individual  1798.0        FWD  4670.0  1814.0  1476.0               5.0
#
#       Fuel Tank Capacity
# 258                  NaN
# 923                 28.0
# 1217                37.0
# 1555                43.0
# 1603                80.0
# 1856                50.0

# %%
# eliminación de registros duplicados
d = d.drop_duplicates()

#Reiniciar el indice
d.reset_index(drop=True, inplace=True)

# %%
# Tasa de cambio de rupias a dólares
tasa_de_cambio = 0.012

d['Price'] = d['Price'] * tasa_de_cambio

# %%
d.head(2)
# Out:
#             Make   Price  Year  Kilometer Fuel Type Transmission   Owner  \
# 0          Honda  6060.0  2017      87150    Petrol       Manual   First
# 1  Maruti Suzuki  5400.0  2014      75000    Diesel       Manual  Second
#
#   Seller Type  Engine Drivetrain  Length   Width  Height  Seating Capacity  \
# 0   Corporate  1198.0        FWD  3990.0  1680.0  1505.0               5.0
# 1  Individual  1248.0        FWD  3995.0  1695.0  1555.0               5.0
#
#    Fuel Tank Capacity
# 0                35.0
# 1                42.0

# %% [markdown]
# ## 5. Visualización de datos

# %% [markdown]
# ### Variables de entrada

# %%
#Lista de variables categóricas
catCols = d.select_dtypes(include = ["object", 'category']).columns.tolist()

d[catCols].head(2)
# Out:
#             Make Fuel Type Transmission   Owner Seller Type Drivetrain
# 0          Honda    Petrol       Manual   First   Corporate        FWD
# 1  Maruti Suzuki    Diesel       Manual  Second  Individual        FWD

# %%
#Lista de variables numéricas

numCols=d.select_dtypes(include = ['float64','int32','int64']).columns.tolist()
d[numCols].head()
# Out:
#      Price  Year  Kilometer  Engine  Length   Width  Height  Seating Capacity  \
# 0   6060.0  2017      87150  1198.0  3990.0  1680.0  1505.0               5.0
# 1   5400.0  2014      75000  1248.0  3995.0  1695.0  1555.0               5.0
# 2   2640.0  2011      67000  1197.0  3585.0  1595.0  1550.0               5.0
# 3   9588.0  2019      37500  1197.0  3995.0  1745.0  1510.0               5.0
# 4  23400.0  2018      69000  2393.0  4735.0  1830.0  1795.0               7.0
#
#    Fuel Tank Capacity
# 0                35.0
# 1                42.0
# 2                35.0
# 3                37.0
# 4                55.0

# %%
#Visualización de frecuencia de instancias para variables categóricas
multiple_plot(3, d , catCols, None, 'countplot', 'Frecuencia de instancias para variables categóricas',30)

# %%
# Distribución de cada variable categórica en el conjunto de datos

for col in catCols:
    print("="*5 + f" {col} " + "="*20)
    print(d[col].value_counts())
    print()
# Out:
# ===== Make ====================
# Maruti Suzuki    439
# Hyundai          348
# Mercedes-Benz    170
# Honda            158
# Toyota           132
# Audi             127
# BMW              120
# Mahindra         119
# Tata              57
# Volkswagen        50
# Ford              48
# Renault           42
# Skoda             39
# Land Rover        33
# Kia               23
# Jeep              18
# Jaguar            17
# MG                17
# Nissan            16
# Volvo             16
# Porsche           15
# MINI              11
# Datsun             8
# Chevrolet          7
# Lexus              6
# Mitsubishi         4
# Ssangyong          3
# Rolls-Royce        3
# Isuzu              2
# Fiat               2
# Maserati           1
# Ferrari            1
# Lamborghini        1
# Name: Make, dtype: int64
#
# ===== Fuel Type ====================
# Diesel          1047
# Petrol           938
# CNG               50
# Electric           7
# LPG                5
# Hybrid             3
# CNG + CNG          1
# Petrol + CNG       1
# Petrol + LPG       1
# Name: Fuel Type, dtype: int64
#
# ===== Transmission ====================
# Manual       1131
# Automatic     922
# Name: Transmission, dtype: int64
#
# ===== Owner ====================
# First               1614
# Second               372
# Third                 42
# UnRegistered Car      21
# Fourth                 3
# 4 or More              1
# Name: Owner, dtype: int64
#
# ===== Seller Type ====================
# Individual                 1991
# Corporate                    57
# Commercial Registration       5
# Name: Seller Type, dtype: int64
#
# ===== Drivetrain ====================
# FWD    1326
# RWD     320
# AWD     271
# Name: Drivetrain, dtype: int64

# %%
#multiple_plot(1, d , 'Make', 'Price', 'boxplot', 'Distribución de la variable próposito vs la edad',90)

# %%
fig, axes = plt.subplots(1, 1, figsize=(16, 6))
ax_cond = axes
sns.boxplot(data=d,
            x='Make',
            y='Price',
            ax=axes,
            palette='nipy_spectral',
            zorder=1
            )
# Personalizar el eje x
ax_cond.set_xticklabels(ax_cond.get_xticklabels(), rotation=90)
# Configurar título
ax_cond.set_title('Distribución de la variable Make vs. el precio', fontsize=14, fontweight="bold", y=1.1)
# Out:
# Text(0.5, 1.1, 'Distribución de la variable Make vs. el precio')

# %%
multiple_plot(3, d , catCols, 'Price', 'boxplot', 'Distribución de la variable Make vs. el Price',30)

# %%
#Visualización de variables numéricas con respecto al precio
multiple_plot(1, d , numCols, None, 'scatterplot', 'Relación entre las variables numéricas',30)

# %% [markdown]
# ### Variable de salida

# %%
#Histográma y caja de bigotes del precio de los vehículos

plt.figure(figsize=(12,4))

plt.subplot(1,2,1)
plt.title('Distribución de precio de vehículos')
sns.distplot(d['Price'])

plt.subplot(1,2,2)
plt.title('Diferencia de precios de vehículos')
sns.boxplot(x=d['Price'], palette='nipy_spectral')

plt.show()

# %%
#Descripción del precio de los vehículos: Total, media, desviación, mínimo, máximo y percentiles 

#Configuración de formato de visualización
pd.set_option('display.float_format', lambda x: '%.0f' % x)

#Descripción
print(d['Price'].describe(percentiles = [0.25,0.50,0.75,0.85,0.90,0.95,0.975,1]))
# Out:
# count     2053
# mean     20417
# std      29034
# min        588
# 25%       5820
# 50%       9900
# 75%      23100
# 85%      37200
# 90%      49800
# 95%      70440
# 97.5%    89394
# 100%    420000
# max     420000
# Name: Price, dtype: float64

# %% [markdown]
# ## 6. Preparación de datos

# %% [markdown]
# ### Valores atípicos de la variable de salida

# %%
#Calculo de valores atípicos


#Calculo de Q1 t Q3
Q1 = np.percentile(d['Price'], 25, interpolation = 'midpoint') 
Q3 = np.percentile(d['Price'], 75, interpolation = 'midpoint') 
  
#Cálculo del rango intercuartil    
IQR = Q3 - Q1 

#Cálculo de valor mínimo y máximo para los valores atípicos
VAInf = Q1 - 1.5*IQR
VASup = Q3 + 1.5*IQR
   
print(f'Valor atípico leve inferior:{VAInf}') 
print(f'Valor atípico leve superior:{VASup}')
# Out:
# Valor atípico leve inferior:-20100.029999999995
# Valor atípico leve superior:49020.018

# %%
# Se eliminan los valores atípicos
d = d.drop(d[d['Price']>VASup].index)

#Reiniciar el indice
d.reset_index(drop=True, inplace=True)

# %%
#Histográma y caja de bigotes del precio de los vehículos

plt.figure(figsize=(12,4))

plt.subplot(1,2,1)
plt.title('Car Price Distribution Plot')
sns.distplot(d['Price'])

plt.subplot(1,2,2)
plt.title('Car Price Spread')
sns.boxplot(x=d['Price'], palette='nipy_spectral')

plt.show()

# %%
#Descripción del precio de los vehículos después de eliminar valores atípicos

print(d['Price'].describe(percentiles = [0.25,0.50,0.75,0.85,0.90,0.95,0.975,1]))
# Out:
# count    1839
# mean    13006
# std     10678
# min       588
# 25%      5400
# 50%      8880
# 75%     17760
# 85%     23898
# 90%     29990
# 95%     37500
# 97.5%   42000
# 100%    48000
# max     48000
# Name: Price, dtype: float64

# %% [markdown]
# ### Imputaciones

# %%
#Identificación de valores nulos para las variables numéricas
for col in d[numCols]:
    print (col, np.sum(pd.isnull(d[col])))
# Out:
# Price 0
# Year 0
# Kilometer 0
# Engine 75
# Length 59
# Width 59
# Height 59
# Seating Capacity 59
# Fuel Tank Capacity 95

# %%
# Registros donde varias características (Length, Length, Height y Seating Capacity) son vacías
d.loc[d['Length'].isna() & d['Width'].isna() & d['Height'].isna() & d['Seating Capacity'].isna()]
# Out:
#                Make  Price  Year  Kilometer     Fuel Type Transmission  \
# 33            Honda  10320  2013      67000        Petrol    Automatic
# 69             Audi  15000  2012      50000        Diesel    Automatic
# 94    Mercedes-Benz  46800  2018      83400        Diesel    Automatic
# 106           Honda   2748  2013      38175        Petrol       Manual
# 135   Maruti Suzuki   2520  2011      58888        Petrol       Manual
# 248             BMW   9600  2012      75576        Diesel    Automatic
# 270   Maruti Suzuki   3600  2011      90000        Petrol       Manual
# 275          Jaguar  22500  2014      66000        Diesel    Automatic
# 287      Volkswagen   3480  2014     125000        Diesel       Manual
# 300            Audi  11700  2012      93417        Diesel    Automatic
# 379   Mercedes-Benz   6120  2007      39000        Petrol    Automatic
# 393          Toyota   5220  2010     120000        Diesel       Manual
# 437   Mercedes-Benz  18000  2012     158000        Petrol    Automatic
# 444   Maruti Suzuki    852  2004      65082        Petrol       Manual
# 445           Honda   3540  2012      66240        Petrol       Manual
# 448        Mahindra   4548  2012      88500        Diesel       Manual
# 464   Mercedes-Benz  12540  2012      75000        Diesel    Automatic
# 518      Volkswagen   4140  2011      50667        Petrol    Automatic
# 554            Audi   8940  2013      72000        Diesel    Automatic
# 574      Volkswagen   4320  2012      80000        Diesel       Manual
# 583          Jaguar  40200  2014      49235        Diesel    Automatic
# 588      Volkswagen   4500  2012      78000        Diesel       Manual
# 657           Honda   3000  2013      70000        Petrol       Manual
# 661          Jaguar  31800  2015      62645        Diesel    Automatic
# 663          Jaguar  33600  2011      70662        Petrol    Automatic
# 732         Hyundai   4020  2013      80500        Petrol       Manual
# 735         Hyundai   3000  2011      75431        Petrol       Manual
# 745           Honda   1200  2002      65494        Petrol       Manual
# 787          Toyota  37200  2014      65000        Diesel    Automatic
# 792   Maruti Suzuki  11700  2022       5000        Petrol       Manual
# 803            Audi  13800  2012      40031        Diesel    Automatic
# 810      Volkswagen   3720  2009     107879        Diesel       Manual
# 840         Hyundai   3300  2011      45000        Petrol       Manual
# 871   Mercedes-Benz  13200  2012      73000        Diesel    Automatic
# 888          Nissan   6600  2013      33000        Petrol    Automatic
# 928      Volkswagen   3300  2011      80000        Petrol       Manual
# 939           Lexus  25200  2007      34000        Petrol    Automatic
# 952             BMW  14400  2012     125000        Diesel    Automatic
# 954   Mercedes-Benz  14400  2000      65000        Petrol    Automatic
# 965         Hyundai   3588  2011      30000        Petrol       Manual
# 976            Audi  48000  2018      66000        Diesel    Automatic
# 983           Honda   9324  2014       9212        Petrol       Manual
# 994      Volkswagen   2880  2010      78000        Petrol       Manual
# 1195     Volkswagen   4140  2011     101923        Petrol       Manual
# 1251           Audi  13800  2013      30000        Diesel    Automatic
# 1289           Audi  11700  2012      56000        Diesel    Automatic
# 1293        Hyundai   2940  2011      41000        Petrol       Manual
# 1370          Honda  10140  2014      80121        Petrol    Automatic
# 1412  Maruti Suzuki   3180  2011      28000        Petrol       Manual
# 1465  Maruti Suzuki   2460  2011      42152        Petrol       Manual
# 1485        Hyundai   4200  2011      84873        Petrol       Manual
# 1509  Maruti Suzuki   2280  2011      58888        Petrol       Manual
# 1619  Maruti Suzuki   4620  2019       2200        Petrol       Manual
# 1659  Maruti Suzuki   1560  1996     100000  Petrol + LPG       Manual
# 1694  Maruti Suzuki   3792  2019      17491        Petrol       Manual
# 1699        Hyundai   3000  2012      72000        Petrol       Manual
# 1723        Porsche  43200  2014      43000        Petrol    Automatic
# 1793           Audi   9300  2012      89000        Diesel    Automatic
# 1808          Honda   2340  2008      57885        Petrol    Automatic
#
#        Owner Seller Type  Engine Drivetrain  Length  Width  Height  \
# 33     First  Individual     NaN        NaN     NaN    NaN     NaN
# 69     First  Individual     NaN        NaN     NaN    NaN     NaN
# 94    Second  Individual     NaN        NaN     NaN    NaN     NaN
# 106    First  Individual     NaN        NaN     NaN    NaN     NaN
# 135   Second  Individual     NaN        NaN     NaN    NaN     NaN
# 248   Second  Individual     NaN        NaN     NaN    NaN     NaN
# 270   Second  Individual     NaN        NaN     NaN    NaN     NaN
# 275    First  Individual     NaN        NaN     NaN    NaN     NaN
# 287    First  Individual     NaN        NaN     NaN    NaN     NaN
# 300    First  Individual     NaN        NaN     NaN    NaN     NaN
# 379    Third  Individual     NaN        NaN     NaN    NaN     NaN
# 393    First  Individual     NaN        NaN     NaN    NaN     NaN
# 437    First  Individual     NaN        NaN     NaN    NaN     NaN
# 444    First  Individual     NaN        NaN     NaN    NaN     NaN
# 445    Third  Individual     NaN        NaN     NaN    NaN     NaN
# 448   Second  Individual     NaN        NaN     NaN    NaN     NaN
# 464   Second  Individual     NaN        NaN     NaN    NaN     NaN
# 518   Second  Individual     NaN        NaN     NaN    NaN     NaN
# 554    First  Individual     NaN        NaN     NaN    NaN     NaN
# 574   Second  Individual     NaN        NaN     NaN    NaN     NaN
# 583    First  Individual     NaN        NaN     NaN    NaN     NaN
# 588    Third  Individual     NaN        NaN     NaN    NaN     NaN
# 657    First  Individual     NaN        NaN     NaN    NaN     NaN
# 661    First  Individual     NaN        NaN     NaN    NaN     NaN
# 663   Second  Individual     NaN        NaN     NaN    NaN     NaN
# 732    First  Individual     NaN        NaN     NaN    NaN     NaN
# 735    First  Individual     NaN        NaN     NaN    NaN     NaN
# 745    First  Individual     NaN        NaN     NaN    NaN     NaN
# 787    First  Individual     NaN        NaN     NaN    NaN     NaN
# 792    First  Individual     NaN        NaN     NaN    NaN     NaN
# 803   Second  Individual     NaN        NaN     NaN    NaN     NaN
# 810   Second  Individual     NaN        NaN     NaN    NaN     NaN
# 840    First  Individual     NaN        NaN     NaN    NaN     NaN
# 871    First  Individual     NaN        NaN     NaN    NaN     NaN
# 888    First  Individual     NaN        NaN     NaN    NaN     NaN
# 928   Second  Individual     NaN        NaN     NaN    NaN     NaN
# 939   Second   Corporate     NaN        NaN     NaN    NaN     NaN
# 952    First  Individual     NaN        NaN     NaN    NaN     NaN
# 954   Second  Individual     NaN        NaN     NaN    NaN     NaN
# 965    Third  Individual     NaN        NaN     NaN    NaN     NaN
# 976    First  Individual     NaN        NaN     NaN    NaN     NaN
# 983    First  Individual     NaN        NaN     NaN    NaN     NaN
# 994   Second  Individual     NaN        NaN     NaN    NaN     NaN
# 1195  Second  Individual     NaN        NaN     NaN    NaN     NaN
# 1251  Second  Individual     NaN        NaN     NaN    NaN     NaN
# 1289  Second  Individual     NaN        NaN     NaN    NaN     NaN
# 1293   First  Individual     NaN        NaN     NaN    NaN     NaN
# 1370  Second  Individual     NaN        NaN     NaN    NaN     NaN
# 1412   First  Individual     NaN        NaN     NaN    NaN     NaN
# 1465   First   Corporate     NaN        NaN     NaN    NaN     NaN
# 1485  Second  Individual     NaN        NaN     NaN    NaN     NaN
# 1509  Second  Individual     NaN        NaN     NaN    NaN     NaN
# 1619   First  Individual     NaN        NaN     NaN    NaN     NaN
# 1659  Second  Individual     NaN        NaN     NaN    NaN     NaN
# 1694   First  Individual     NaN        NaN     NaN    NaN     NaN
# 1699   Third  Individual     NaN        NaN     NaN    NaN     NaN
# 1723  Second  Individual     NaN        NaN     NaN    NaN     NaN
# 1793  Second  Individual     NaN        NaN     NaN    NaN     NaN
# 1808   First  Individual     NaN        NaN     NaN    NaN     NaN
#
#       Seating Capacity  Fuel Tank Capacity
# 33                 NaN                 NaN
# 69                 NaN                 NaN
# 94                 NaN                 NaN
# 106                NaN                 NaN
# 135                NaN                 NaN
# 248                NaN                 NaN
# 270                NaN                 NaN
# 275                NaN                 NaN
# 287                NaN                 NaN
# 300                NaN                 NaN
# 379                NaN                 NaN
# 393                NaN                 NaN
# 437                NaN                 NaN
# 444                NaN                 NaN
# 445                NaN                 NaN
# 448                NaN                 NaN
# 464                NaN                 NaN
# 518                NaN                 NaN
# 554                NaN                 NaN
# 574                NaN                 NaN
# 583                NaN                 NaN
# 588                NaN                 NaN
# 657                NaN                 NaN
# 661                NaN                 NaN
# 663                NaN                 NaN
# 732                NaN                 NaN
# 735                NaN                 NaN
# 745                NaN                 NaN
# 787                NaN                 NaN
# 792                NaN                 NaN
# 803                NaN                 NaN
# 810                NaN                 NaN
# 840                NaN                 NaN
# 871                NaN                 NaN
# 888                NaN                 NaN
# 928                NaN                 NaN
# 939                NaN                 NaN
# 952                NaN                 NaN
# 954                NaN                 NaN
# 965                NaN                 NaN
# 976                NaN                 NaN
# 983                NaN                 NaN
# 994                NaN                 NaN
# 1195               NaN                 NaN
# 1251               NaN                 NaN
# 1289               NaN                 NaN
# 1293               NaN                 NaN
# 1370               NaN                 NaN
# 1412               NaN                 NaN
# 1465               NaN                 NaN
# 1485               NaN                 NaN
# 1509               NaN                 NaN
# 1619               NaN                 NaN
# 1659               NaN                 NaN
# 1694               NaN                 NaN
# 1699               NaN                 NaN
# 1723               NaN                 NaN
# 1793               NaN                 NaN
# 1808               NaN                 NaN

# %%
# Se eliminan aquiellas donde todas sus variables numéricas son vacías NaN
d = d.dropna(subset=['Length', 'Width', 'Height', 'Seating Capacity'])

# %%
#Identificación de valores nulos para las variables numéricas
for col in d[numCols]:
    print (col, np.sum(pd.isnull(d[col])))
# Out:
# Price 0
# Year 0
# Kilometer 0
# Engine 16
# Length 0
# Width 0
# Height 0
# Seating Capacity 0
# Fuel Tank Capacity 36

# %%
#Imputación de variables numéricas por medio de KNNImputer

# crear un objeto KNNImputer con k=5
imputer = KNNImputer(n_neighbors=5)

# imputar los valores faltantes en el dataframe
df_imputed = imputer.fit_transform(d[numCols])

# convertir el arreglo numpy devuelto por el imputer en un dataframe
df_imputed = pd.DataFrame(df_imputed, columns=numCols)

# imprimir el dataframe con los valores imputados
df_imputed.head()
# Out:
#    Price  Year  Kilometer  Engine  Length  Width  Height  Seating Capacity  \
# 0   6060  2017      87150    1198    3990   1680    1505                 5
# 1   5400  2014      75000    1248    3995   1695    1555                 5
# 2   2640  2011      67000    1197    3585   1595    1550                 5
# 3   9588  2019      37500    1197    3995   1745    1510                 5
# 4  23400  2018      69000    2393    4735   1830    1795                 7
#
#    Fuel Tank Capacity
# 0                  35
# 1                  42
# 2                  35
# 3                  37
# 4                  55

# %%
#Identificación de valores nulos para las variables numéricas
for col in d[catCols]:
    print (col, np.sum(pd.isnull(d[col])))
# Out:
# Make 0
# Fuel Type 0
# Transmission 0
# Owner 0
# Seller Type 0
# Drivetrain 72

# %%
# Graficar la frecuencia de Drivetrain

plt.figure(figsize=(5, 3))
d['Drivetrain'].value_counts().plot(kind='bar', color='skyblue')
plt.title('Frecuencia de Drivetrain')
plt.xlabel('Drivetrain')
plt.ylabel('Frecuencia')
plt.xticks(rotation=0)  # Rotar etiquetas en el eje x 
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
#Imputación de variables categóricas por medio de SimpleImputer

# crear un objeto SimpleImputer con la estrategia de más frecuente
imputer = SimpleImputer(strategy='most_frequent')

# imputar los valores faltantes en el dataframe
df_imputed2 = imputer.fit_transform(d[catCols])

# convertir el arreglo numpy devuelto por el imputer en un dataframe
df_imputed2 = pd.DataFrame(df_imputed2, columns=catCols)

#imprimir el dataframe con los valores imputados
df_imputed2
# Out:
#                Make Fuel Type Transmission   Owner Seller Type Drivetrain
# 0             Honda    Petrol       Manual   First   Corporate        FWD
# 1     Maruti Suzuki    Diesel       Manual  Second  Individual        FWD
# 2           Hyundai    Petrol       Manual   First  Individual        FWD
# 3            Toyota    Petrol       Manual   First  Individual        FWD
# 4            Toyota    Diesel       Manual   First  Individual        RWD
# ...             ...       ...          ...     ...         ...        ...
# 1775  Maruti Suzuki    Petrol       Manual  Second  Individual        FWD
# 1776       Mahindra    Diesel       Manual   First  Individual        FWD
# 1777        Hyundai    Petrol       Manual  Second  Individual        FWD
# 1778           Ford    Petrol       Manual   First  Individual        FWD
# 1779       Mahindra    Diesel       Manual   First  Individual        RWD
#
# [1780 rows x 6 columns]

# %%
#Integración de los dos dataframes (categoricos y numéricos) después de la imputación
d = pd.merge(df_imputed, df_imputed2, left_index=True, right_index=True)
d.head()
# Out:
#    Price  Year  Kilometer  Engine  Length  Width  Height  Seating Capacity  \
# 0   6060  2017      87150    1198    3990   1680    1505                 5
# 1   5400  2014      75000    1248    3995   1695    1555                 5
# 2   2640  2011      67000    1197    3585   1595    1550                 5
# 3   9588  2019      37500    1197    3995   1745    1510                 5
# 4  23400  2018      69000    2393    4735   1830    1795                 7
#
#    Fuel Tank Capacity           Make Fuel Type Transmission   Owner  \
# 0                  35          Honda    Petrol       Manual   First
# 1                  42  Maruti Suzuki    Diesel       Manual  Second
# 2                  35        Hyundai    Petrol       Manual   First
# 3                  37         Toyota    Petrol       Manual   First
# 4                  55         Toyota    Diesel       Manual   First
#
#   Seller Type Drivetrain
# 0   Corporate        FWD
# 1  Individual        FWD
# 2  Individual        FWD
# 3  Individual        FWD
# 4  Individual        RWD

# %%
#verificación de la imputación: No existen valores nulos
for col in d.columns:
    print (col, np.sum(pd.isnull(d[col])))
# Out:
# Price 0
# Year 0
# Kilometer 0
# Engine 0
# Length 0
# Width 0
# Height 0
# Seating Capacity 0
# Fuel Tank Capacity 0
# Make 0
# Fuel Type 0
# Transmission 0
# Owner 0
# Seller Type 0
# Drivetrain 0

# %% [markdown]
# ### Valores atípicos para las variables de entrada

# %%
#utilización de LocalOutlierFactor con 13 vecinos para identificar valores atípicos en las variables de entrada


# crear un objeto LocalOutlierFactor con n_neighbors=13
lof = LocalOutlierFactor(n_neighbors=13, contamination=0.1)

# identificar los valores atípicos por medio de lof 
y_pred = lof.fit_predict(d[numCols])

# Identificar los índices de los valores atípicos
outliers = y_pred == -1

print('Indices de valores atípicos: ', d[outliers].index.tolist())
# Out:
# Indices de valores atípicos:  [2, 39, 66, 86, 91, 105, 106, 109, 111, 114, 124, 127, 139, 150, 157, 167, 174, 185, 188, 207, 213, 217, 218, 233, 241, 242, 274, 284, 285, 339, 344, 348, 365, 382, 395, 396, 397, 410, 432, 434, 447, 453, 455, 462, 463, 464, 490, 504, 515, 517, 520, 533, 536, 540, 550, 557, 564, 590, 595, 600, 605, 619, 620, 630, 636, 639, 641, 642, 644, 676, 677, 683, 685, 695, 705, 735, 740, 750, 751, 753, 768, 769, 779, 791, 793, 811, 842, 850, 864, 870, 880, 894, 898, 901, 933, 934, 957, 969, 984, 986, 990, 1004, 1010, 1026, 1040, 1041, 1042, 1043, 1050, 1051, 1070, 1096, 1098, 1141, 1145, 1153, 1163, 1168, 1174, 1188, 1208, 1211, 1229, 1234, 1260, 1263, 1282, 1291, 1297, 1306, 1313, 1314, 1315, 1324, 1327, 1385, 1386, 1389, 1393, 1395, 1399, 1406, 1410, 1411, 1413, 1415, 1417, 1420, 1426, 1473, 1483, 1515, 1522, 1551, 1553, 1556, 1573, 1602, 1607, 1611, 1615, 1637, 1650, 1659, 1665, 1674, 1687, 1690, 1699, 1720, 1721, 1723, 1729, 1730, 1744, 1746, 1750, 1767]

# %%
# Eliminar los valores atípicos del dataframe original
d = d.loc[~outliers]

# %% [markdown]
# ### Transformaciones

# %%
#Eliminación de categorias pequeñas para la variable Fuel Type

d['Fuel Type'].value_counts().sort_values(ascending=False)
# Out:
# Petrol          777
# Diesel          767
# CNG              48
# Electric          7
# CNG + CNG         1
# LPG               1
# Petrol + CNG      1
# Name: Fuel Type, dtype: int64

# %%
#Diccionario con los reemplazos a realizar
reemplazos = { "CNG": "Otro" 
              ,"Electric": "Otro"
              , "LPG": "Otro"
              , "CNG + CNG": "Otro"
              , "Petrol + CNG": "Otro"
              , "Petrol + LPG": "Otro"}


#Se reemplazan los valores de acuerdo con el diccionario creado anteriormente
d['Fuel Type'] = d['Fuel Type'].map(reemplazos).fillna(d['Fuel Type'])

#Visualización de las nuevos valores agrupados para la categoria 'Fuel Type'
d['Fuel Type'].value_counts().sort_values(ascending=False)
# Out:
# Petrol    777
# Diesel    767
# Otro       58
# Name: Fuel Type, dtype: int64

# %%
#pd.set_option('display.max_rows')
pd.reset_option('display.max_rows')

# %%
#Discretización (binning) de la variable 'Make'

#Cantidad de instancias por Make
d['Make'].value_counts().sort_values(ascending=False)
# Out:
# Maruti Suzuki    400
# Hyundai          315
# Honda            142
# Toyota           104
# Mahindra         101
# Audi              87
# Mercedes-Benz     72
# BMW               54
# Tata              50
# Ford              42
# Volkswagen        41
# Renault           40
# Skoda             33
# Kia               21
# MG                16
# Nissan            15
# Jeep              13
# Volvo             10
# MINI               9
# Jaguar             8
# Datsun             7
# Land Rover         6
# Chevrolet          6
# Ssangyong          3
# Isuzu              2
# Fiat               2
# Mitsubishi         2
# Lexus              1
# Name: Make, dtype: int64

# %%
#Se Calcula la mediana por marca 'Make'

d.groupby('Make').Price.median().sort_values(ascending=False)
# Out:
# Make
# Lexus           46800
# Land Rover      39900
# Jaguar          38694
# MINI            38400
# BMW             31500
# Mercedes-Benz   26850
# Audi            26400
# Isuzu           23346
# MG              21840
# Volvo           20934
# Jeep            19020
# Kia             18300
# Toyota          17880
# Mitsubishi      16650
# Skoda           15600
# Mahindra        11580
# Ssangyong       10800
# Tata             9930
# Hyundai          7188
# Honda            7020
# Volkswagen       6900
# Ford             6720
# Maruti Suzuki    6540
# Nissan           5400
# Renault          5034
# Chevrolet        4320
# Fiat             3660
# Datsun           3240
# Name: Price, dtype: float64

# %%
#Gráfica de visualización de precio medio por marca 'Make'
plt.figure(figsize=(6, 6))

d.groupby('Make').Price.median().sort_values(ascending=True).plot.barh()
plt.title("Precio medio por marca")
plt.ylabel("Make")
plt.xlabel("Price")
plt.show()

# %%
df= d.groupby('Make').Price.median().sort_values(ascending=False)
df=df.reset_index()
df.head(10)
# Out:
#             Make  Price
# 0          Lexus  46800
# 1     Land Rover  39900
# 2         Jaguar  38694
# 3           MINI  38400
# 4            BMW  31500
# 5  Mercedes-Benz  26850
# 6           Audi  26400
# 7          Isuzu  23346
# 8             MG  21840
# 9          Volvo  20934

# %%
#Se crea una nueva variable que establece el un bin de acuerdo al precio medio por marca

#Configuración de formato de visualización
pd.set_option('display.float_format', lambda x: '%.4f' % x)

#Se define el numero de bins que se quieren crear 
numBins = 5

#Se identifica el maximo valor
max_value = df["Price"].max()

#Se crea la nueva variable PriceRange dando el mayor valor al mayor precio medio
df['PriceRange'] = df['Price'].apply(lambda x: int(round(x / (max_value/numBins))))


df
# Out:
#              Make      Price  PriceRange
# 0           Lexus 46800.0000           5
# 1      Land Rover 39900.0000           4
# 2          Jaguar 38694.0000           4
# 3            MINI 38400.0000           4
# 4             BMW 31500.0000           3
# 5   Mercedes-Benz 26850.0000           3
# 6            Audi 26400.0000           3
# 7           Isuzu 23346.0000           2
# 8              MG 21839.9940           2
# 9           Volvo 20933.9880           2
# 10           Jeep 19020.0000           2
# 11            Kia 18300.0000           2
# 12         Toyota 17880.0000           2
# 13     Mitsubishi 16650.0000           2
# 14          Skoda 15600.0000           2
# 15       Mahindra 11580.0000           1
# 16      Ssangyong 10800.0000           1
# 17           Tata  9930.0000           1
# 18        Hyundai  7188.0000           1
# 19          Honda  7020.0000           1
# 20     Volkswagen  6900.0000           1
# 21           Ford  6720.0000           1
# 22  Maruti Suzuki  6540.0000           1
# 23         Nissan  5400.0000           1
# 24        Renault  5034.0000           1
# 25      Chevrolet  4320.0000           0
# 26           Fiat  3660.0000           0
# 27         Datsun  3240.0000           0

# %%
#Se adiciona la nueva variable al dataset original
d=pd.merge(d, df[['Make','PriceRange']], on='Make', how='left')

#Se elimina la variable Make
d = d.drop(['Make'], axis=1)

d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1602 entries, 0 to 1601
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Price               1602 non-null   float64
#  1   Year                1602 non-null   float64
#  2   Kilometer           1602 non-null   float64
#  3   Engine              1602 non-null   float64
#  4   Length              1602 non-null   float64
#  5   Width               1602 non-null   float64
#  6   Height              1602 non-null   float64
#  7   Seating Capacity    1602 non-null   float64
#  8   Fuel Tank Capacity  1602 non-null   float64
#  9   Fuel Type           1602 non-null   object
#  10  Transmission        1602 non-null   object
#  11  Owner               1602 non-null   object
#  12  Seller Type         1602 non-null   object
#  13  Drivetrain          1602 non-null   object
#  14  PriceRange          1602 non-null   int64
# dtypes: float64(9), int64(1), object(5)
# memory usage: 200.2+ KB

# %%
numCols.append('PriceRange')
numCols
# Out:
# ['Price',
#  'Year',
#  'Kilometer',
#  'Engine',
#  'Length',
#  'Width',
#  'Height',
#  'Seating Capacity',
#  'Fuel Tank Capacity',
#  'PriceRange']

# %%
catCols.remove('Make')
catCols
# Out:
# ['Fuel Type', 'Transmission', 'Owner', 'Seller Type', 'Drivetrain']

# %% [markdown]
# ### Datos de prueba

# %%
# Porcentaje de filas para la primera parte (por ejemplo, 90%)
percentage_first_part = 0.90

# Número de filas para la primera parte
n_rows_part1 = int(len(d) * percentage_first_part)

# Obtener índices aleatorios para la primer parte
indices_part1 = d.sample(n=n_rows_part1, random_state=123).index

# Obtener índices para la segunda parte (resto de las filas)
indices_part2 = d.index.difference(indices_part1)

# Dividir el DataFrame en dos partes
df = d.loc[indices_part1]
dp = d.loc[indices_part2]

# %%
dp.shape
# Out:
# (161, 15)

# %% [markdown]
# ## 7. Exportar el dataset

# %%
# Exportamos el dataframe a un archivo CSV
df.to_csv('./datasets/01_carDetailsV4_Prep.csv', index=False)
dp.to_csv('./datasets/01_carDetailsV4_Prue.csv', index=False)

# %% [markdown]
# ### Referencias
#
#
# - *Dataset:*
#     - https://www.kaggle.com/datasets/nehalbirla/vehicle-dataset-from-cardekho?select=car+details+v4.csv
#
#
# - *Machine learning con Python y Scikit-learn:*
#     - https://www.cienciadedatos.net/documentos/py06_machine_learning_python_scikitlearn.html
#
#
# - *LocalOutlierFactor:*
#     - https://scikit-learn.org/stable/modules/generated/sklearn.neighbors.LocalOutlierFactor.html
#
#
# - *scikit-learn:*
#     - https://scikit-learn.org/stable/
#     - https://scikit-learn.org/stable/user_guide.html
#
#
# - *Gráficas con  seaborn:*
#     - https://ichi.pro/es/como-utilizar-python-seaborn-para-analisis-de-datos-exploratorios-28897898172180
